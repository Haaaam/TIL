# %% [markdown]
# #### 넘파이로 텐서 만들기(벡터와 행렬 만들기)

# %%
import torch
import numpy as np

# %%
x=torch.empty(5,4)
print(x)

# %%
#1로 채우기
torch.ones(3,3)

# %%
#0으로 채우기
torch.zeros(2)

# %%
torch.rand(5,6)

# %%
l=[13,4]
r=np.array([4,56,7])

# %%
torch.tensor(l)

# %%
torch.tensor(r)

# %%
type(x)

# %%
x=torch.rand(2,2)
y=torch.rand(2,2)
print(x)
print(y)

# %%
x+y

# %%
torch.add(x,y)

# %%
y.add(x)

# %%
y

# %%
y.add_(x) #y에 x를 더해서 y를 대체한다.

# %%
y[1,1]

# %%
y[:,1]

# %%
x=torch.rand(8,8)
print(x)

# %%
# x라는 텐서를 1x64로 변경
x.view(64)

# %%
#x라는 텐서를 4x16으로 변경
x.view(4,16)

# %%
x.view(-1,4,4)

# %%
y=x.numpy()
print(y)

# %%
type(y)

# %%
x=torch.ones(1)

# %%
x

# %%
# 1개의 요소를 가지는 텐서가 있다면, .itme()을 이용하여 python에서의 숫자 데이터처럼 값을 얻을 수 있다.
x.item()
