# %% [markdown]
# #### 5 steps of using TensorBoard
# ![캡처.PNG](data:image/png;base64,...)

# %%
# Add scope for better graph hierarchy

with tf.name_scope("layer1") as scope:
    W1=tf.Variable(tf.random_normal([2,2]),name='weight1')
    b1=tf.Variable(tf.random_normal([1]),name='bias1')
    layer1=tf.sigmoid(tf.matmul(X,W1)+b1)

    W1_hist=tf.summary.histogram('weights1',W1)
    b1_hist=tf.summary.histogram('biases1',b1)
    layer1_hist=tf.summary.histogram('layer1',layer1)

with tf.name_scope("layer2") as scope:
    W2=tf.Variable(tf.random_normal([2,1]),name='weight2')
    b2=tf.Variable(tf.random_normal([1]),name='bias2')
    hypothesis=tf.sigmoid(tf.matmul(layer1,W2)+b2)

    W2_hist=tf.summary.histogram("weights2",W2)
    b2_hist=tf.summary.histogram("biases2",b2)
    hypothesis_hist=tf.summary.histogram("hypothesis",hypothesis)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-cf472ec7c390> in <module>()
#       1 # Add scope for better graph hierarchy
#       2
# ----> 3 with tf.name_scope("layer1") as scope:
#       4     W1=tf.Variable(tf.random_normal([2,2]),name='weight1')
#       5     b1=tf.Variable(tf.random_normal([1]),name='bias1')
#
# NameError: name 'tf' is not defined

# %%
#Summary
summary=tf.summary.merge_all()

sess=tf.Session()
sess.run(tf.global_variables_initializer())

writer=tf.summary.FileWriter(TB_SUMMARY_DIR)
writer.add_graph(sess.graph)#Add graph in the tensorboard
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-450d1a77eff4> in <module>()
#       1 #Summary
# ----> 2 summary=tf.summary.merge_all()
#       3
#       4 sess=tf.Session()
#       5 sess.run(tf.global_variables_initializer())
#
# NameError: name 'tf' is not defined

# %%
#Run merged summary and write(add summary)

s, _= sess.run([summary,optimizer],feed_dict=feed_dict)
writer.add_summary(s,global_step=global_step)
global_step+=1

#Launch Tensorboard(local)

writer=tf.summary.FileWriter('%load_ext tensorboard')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d51876c45d3f> in <module>()
#       1 #Run merged summary and write(add summary)
#       2
# ----> 3 s, _= sess.run([summary,optimizer],feed_dict=feed_dict)
#       4 writer.add_summary(s,global_step=global_step)
#       5 global_step+=1
#
# NameError: name 'sess' is not defined
